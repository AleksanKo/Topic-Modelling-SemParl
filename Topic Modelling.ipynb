# %% [markdown]
# ## Topic modelling with Scikit-learn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
import pandas as pd
import pyLDAvis
import pyLDAvis.sklearn
import re

# %%
n_samples = 2000
n_features = 1000
n_components = 10
n_top_words = 20

# %%
data = pd.read_csv('final.csv', sep='\t',header = None,names = ['ID','Date','Time','Speaker','Party','Text'])
data
# Out:
#           ID        Date      Time               Speaker     Party  \
# 0          0  2018-05-16  14:11:55    Sinuhe Wallinheimo       kok
# 1          1  2018-05-16  14:15:49          Kai Mykkänen  minister
# 2          2  2018-05-16  14:19:26     Markus Mustajärvi       vas
# 3          3  2018-05-16  14:20:32       Maria Tolppanen        sd
# 4          4  2018-05-16  14:21:37       Jari Myllykoski       vas
# ...      ...         ...       ...                   ...       ...
# 56654  56654  2019-02-14  21:48:56            Sami Savio        ps
# 56655  56655  2019-02-14  21:52:15         Sirpa Paatero        sd
# 56656  56656  2019-02-14  21:54:50             Mia Laiho       kok
# 56657  56657  2019-02-14  21:58:01         Ben Zyskowicz       kok
# 56658  56658  2019-02-14  22:00:41  Hannakaisa Heikkinen      kesk
#
#                                                     Text
# 0       Arvoisa puhemies! Lähetekeskusteluun olemme s...
# 1       Arvoisa puhemies! Käsillä on todella hallituk...
# 2      Arvoisa puhemies! Ministeri maalasi kyllä aika...
# 3       Arvoisa puhemies! Tässä nyt täytyy ensin tode...
# 4       Arvoisa herra puhemies! Kaksi tässä edellä kä...
# ...                                                  ...
# 56654  Arvoisa puhemies! Vanhustenhoidon tila on tosi...
# 56655  Arvoisa rouva puhemies! Kun tässä useammassa p...
# 56656  Arvoisa puhemies! Sote-muutoksella nimenomaan ...
# 56657  Arvoisa rouva puhemies! Kun nyt puhujalistan v...
# 56658  Arvoisa rouva puhemies! Tänään ja viime viikko...
#
# [56659 rows x 6 columns]

# %%
stopwords = ["aiemmin","aika","aikaa","aikaan","aikaisemmin","aikaisin","aikajen","aikana","aikoina","aikoo","aikovat","aina","ainakaan","ainakin","ainoa","ainoat","aiomme","aion","aiotte","aist","aivan","ajan","alas","alemmas","alkuisin","alkuun","alla","alle","aloitamme","aloitan","aloitat","aloitatte","aloitattivat","aloitettava","aloitettevaksi","aloitettu","aloitimme","aloitin","aloitit","aloititte","aloittaa","aloittamatta","aloitti","aloittivat","alta","aluksi","alussa","alusta","annettavaksi","annetteva","annettu","ansiosta","antaa","antamatta","antoi","aoua","apu","asia","asiaa","asian","asiasta","asiat","asioiden","asioihin","asioita","asti","avuksi","avulla","avun","avutta","edelle","edelleen","edellä","edeltä","edemmäs","edes","edessä","edestä","ehkä","ei","eikä","eilen","eivät","eli","ellei","elleivät","ellemme","ellen","ellet","ellette","emme","en","enemmän","eniten","ennen","ensi","ensimmäinen","ensimmäiseksi","ensimmäisen","ensimmäisenä","ensimmäiset","ensimmäisiksi","ensimmäisinä","ensimmäisiä","ensimmäistä","ensin","entinen","entisen","entisiä","entisten","entistä","enää","eri","erittäin","erityisesti","eräiden","eräs","eräät","esi","esiin","esillä","esimerkiksi","et","eteen","etenkin","etessa","ette","ettei","että","haikki","halua","haluaa","haluamatta","haluamme","haluan","haluat","haluatte","haluavat","halunnut","halusi","halusimme","halusin","halusit","halusitte","halusivat","halutessa","haluton","he","hei","heidän","heidät","heihin","heille","heillä","heiltä","heissä","heistä","heitä","helposti","heti","hetkellä","hieman","hitaasti","hoikein","huolimatta","huomenna","hyvien","hyviin","hyviksi","hyville","hyviltä","hyvin","hyvinä","hyvissä","hyvistä","hyviä","hyvä","hyvät","hyvää","hän","häneen","hänelle","hänellä","häneltä","hänen","hänessä","hänestä","hänet","häntä","ihan","ilman","ilmeisesti","itse","itsensä","itseään","ja","jo","johon","joiden","joihin","joiksi","joilla","joille","joilta","joina","joissa","joista","joita","joka","jokainen","jokin","joko","joksi","joku","jolla","jolle","jolloin","jolta","jompikumpi","jona","jonka","jonkin","jonne","joo","jopa","jos","joskus","jossa","josta","jota","jotain","joten","jotenkin","jotenkuten","jotka","jotta","jouduimme","jouduin","jouduit","jouduitte","joudumme","joudun","joudutte","joukkoon","joukossa","joukosta","joutua","joutui","joutuivat","joutumaan","joutuu","joutuvat","juuri","jälkeen","jälleen","jää","kahdeksan","kahdeksannen","kahdella","kahdelle","kahdelta","kahden","kahdessa","kahdesta","kahta","kahteen","kai","kaiken","kaikille","kaikilta","kaikkea","kaikki","kaikkia","kaikkiaan","kaikkialla","kaikkialle","kaikkialta","kaikkien","kaikkin","kaksi","kannalta","kannattaa","kanssa","kanssaan","kanssamme","kanssani","kanssanne","kanssasi","kauan","kauemmas","kaukana","kautta","kehen","keiden","keihin","keiksi","keille","keillä","keiltä","keinä","keissä","keistä","keitten","keittä","keitä","keneen","keneksi","kenelle","kenellä","keneltä","kenen","kenenä","kenessä","kenestä","kenet","kenettä","kennessästä","kenties","kerran","kerta","kertaa","keskellä","kesken","keskimäärin","ketkä","ketä","kiitos","kohti","koko","kokonaan","kolmas","kolme","kolmen","kolmesti","koska","koskaan","kovin","kuin","kuinka","kuinkan","kuitenkaan","kuitenkin","kuka","kukaan","kukin","kukka","kumpainen","kumpainenkaan","kumpi","kumpikaan","kumpikin","kun","kuten","kuuden","kuusi","kuutta","kylliksi","kyllä","kymmenen","kyse","liian","liki","lisäksi","lisää","lla","luo","luona","lähekkäin","lähelle","lähellä","läheltä","lähemmäs","lähes","lähinnä","lähtien","läpi","mahdollisimman","mahdollista","me","meidän","meidät","meihin","meille","meillä","meiltä","meissä","meistä","meitä","melkein","melko","menee","meneet","menemme","menen","menet","menette","menevät","meni","menimme","menin","menit","menivät","mennessä","mennyt","menossa","mihin","mikin","miksi","mikä","mikäli","mikään","mille","milloin","milloinkan","millä","miltä","minkä","minne","minua","minulla","minulle","minulta","minun","minussa","minusta","minut","minuun","minä","missä","mistä","miten","mitkä","mitä","mitään","moi","molemmat","mones","monesti","monet","moni","moniaalla","moniaalle","moniaalta","monta","muassa","muiden","muita","muka","mukaan","mukaansa","mukana","mutta","muu","muualla","muualle","muualta","muuanne","muulloin","muun","muut","muuta","muutama","muutaman","muuten","myöhemmin","myös","myöskin","myöskään","myötä","ne","neljä","neljän","neljää","niiden","niihin","niiksi","niille","niillä","niiltä","niin","niinä","niissä","niistä","niitä","noiden","noihin","noiksi","noilla","noille","noilta","noin","noina","noissa","noista","noita","nopeammin","nopeasti","nopeiten","nro","nuo","nyt","näiden","näihin","näiksi","näille","näillä","näiltä","näin","näinä","näissä","näissähin","näissälle","näissältä","näissästä","näistä","näitä","nämä","ohi","oikea","oikealla","oikein","ole","olemme","olen","olet","olette","oleva","olevan","olevat","oli","olimme","olin","olisi","olisimme","olisin","olisit","olisitte","olisivat","olit","olitte","olivat","olla","olleet","olli","ollut","oma","omaa","omaan","omaksi","omalle","omalta","oman","omassa","omat","omia","omien","omiin","omiksi","omille","omilta","omissa","omista","on","onkin","onko","ovat","paikoittain","paitsi","pakosti","paljon","paremmin","parempi","parhaillaan","parhaiten","perusteella","peräti","pian","pieneen","pieneksi","pienelle","pienellä","pieneltä","pienempi","pienestä","pieni","pienin","poikki","puolesta","puolestaan","päälle","runsaasti","saakka","sadam","sama","samaa","samaan","samalla","samallalta","samallassa","samallasta","saman","samat","samoin","sata","sataa","satojen","se","seitsemän","sekä","sen","seuraavat","siellä","sieltä","siihen","siinä","siis","siitä","sijaan","siksi","sille","silloin","sillä","silti","siltä","sinne","sinua","sinulla","sinulle","sinulta","sinun","sinussa","sinusta","sinut","sinuun","sinä","sisäkkäin","sisällä","siten","sitten","sitä","ssa","sta","suoraan","suuntaan","suuren","suuret","suuri","suuria","suurin","suurten","taa","taas","taemmas","tahansa","tai","takaa","takaisin","takana","takia","tallä","tapauksessa","tarpeeksi","tavalla","tavoitteena","te","teidän","teidät","teihin","teille","teillä","teiltä","teissä","teistä","teitä","tietysti","todella","toinen","toisaalla","toisaalle","toisaalta","toiseen","toiseksi","toisella","toiselle","toiselta","toisemme","toisen","toisensa","toisessa","toisesta","toista","toistaiseksi","toki","tosin","tuhannen","tuhat","tule","tulee","tulemme","tulen","tulet","tulette","tulevat","tulimme","tulin","tulisi","tulisimme","tulisin","tulisit","tulisitte","tulisivat","tulit","tulitte","tulivat","tulla","tulleet","tullut","tuntuu","tuo","tuohon","tuoksi","tuolla","tuolle","tuolloin","tuolta","tuon","tuona","tuonne","tuossa","tuosta","tuota","tuotä","tuskin","tykö","tähän","täksi","tälle","tällä","tällöin","tältä","tämä","tämän","tänne","tänä","tänään","tässä","tästä","täten","tätä","täysin","täytyvät","täytyy","täällä","täältä","ulkopuolella","usea","useasti","useimmiten","usein","useita","uudeksi","uudelleen","uuden","uudet","uusi","uusia","uusien","uusinta","uuteen","uutta","vaan","vahemmän","vai","vaiheessa","vaikea","vaikean","vaikeat","vaikeilla","vaikeille","vaikeilta","vaikeissa","vaikeista","vaikka","vain","varmasti","varsin","varsinkin","varten","vasen","vasenmalla","vasta","vastaan","vastakkain","vastan","verran","vielä","vierekkäin","vieressä","vieri","viiden","viime","viimeinen","viimeisen","viimeksi","viisi","voi","voidaan","voimme","voin","voisi","voit","voitte","voivat","vuoden","vuoksi","vuosi","vuosien","vuosina","vuotta","vähemmän","vähintään","vähiten","vähän","välillä","yhdeksän","yhden","yhdessä","yhteen","yhteensä","yhteydessä","yhteyteen","yhtä","yhtäälle","yhtäällä","yhtäältä","yhtään","yhä","yksi","yksin","yksittäin","yleensä","ylemmäs","yli","ylös","ympäri","älköön","älä"]

# %%
data['Text'] = [''.join([i for i in s if not i.isdigit()]) for s in data['Text']]
data['Text'] = [re.sub(r'[^\w]', ' ', i) for i in data['Text']]
data['Text'] = [re.sub(r' +', ' ', i) for i in data['Text']]

# %%
data['Text'][0:5]
# Out:
# 0     Arvoisa puhemies Lähetekeskusteluun olemme sa...
# 1     Arvoisa puhemies Käsillä on todella hallituks...
# 2    Arvoisa puhemies Ministeri maalasi kyllä aika ...
# 3     Arvoisa puhemies Tässä nyt täytyy ensin todet...
# 4     Arvoisa herra puhemies Kaksi tässä edellä käy...
# Name: Text, dtype: object

# %%
# Creating a vectorizer
vectorizer = CountVectorizer(min_df=5, max_df=0.9, lowercase=True, stop_words = stopwords,analyzer='word')
data_vectorized = vectorizer.fit_transform(data['Text'])

# %%
NUM_TOPICS = 30

# %%
lda = LatentDirichletAllocation(n_components=NUM_TOPICS, max_iter=20, learning_method='online',verbose=True)
data_lda = lda.fit_transform(data_vectorized)
# Out:
# iteration: 1 of max_iter: 20
# iteration: 2 of max_iter: 20
# iteration: 3 of max_iter: 20
# iteration: 4 of max_iter: 20
# iteration: 5 of max_iter: 20
# iteration: 6 of max_iter: 20
# iteration: 7 of max_iter: 20
# iteration: 8 of max_iter: 20
# iteration: 9 of max_iter: 20
# iteration: 10 of max_iter: 20
# iteration: 11 of max_iter: 20
# iteration: 12 of max_iter: 20
# iteration: 13 of max_iter: 20
# iteration: 14 of max_iter: 20
# iteration: 15 of max_iter: 20
# iteration: 16 of max_iter: 20
# iteration: 17 of max_iter: 20
# iteration: 18 of max_iter: 20
# iteration: 19 of max_iter: 20
# iteration: 20 of max_iter: 20

# %%
nmf = NMF(n_components=NUM_TOPICS,verbose=True)
data_nmf = nmf.fit_transform(data_vectorized)
# Out:
# violation: 1.0
# violation: 0.42242806827398877
# violation: 0.30098928539592984
# violation: 0.20296844468700173
# violation: 0.1441958424901776
# violation: 0.10098172501748533
# violation: 0.07440675875146108
# violation: 0.06417338982864802
# violation: 0.059323937770265664
# violation: 0.04959033349207574
# violation: 0.037453062073613035
# violation: 0.02686774929748703
# violation: 0.020539486990540673
# violation: 0.01614233669871793
# violation: 0.013173089408209679
# violation: 0.01116566109416175
# violation: 0.009694925662787847
# violation: 0.00863257382732034
# violation: 0.007846571625128482
# violation: 0.007366157756440032
# violation: 0.0070672207183165095
# violation: 0.006922536866653688
# violation: 0.0068339931526894965
# violation: 0.006784529213583204
# violation: 0.006745153402054493
# violation: 0.006708070658309213
# violation: 0.006660264129081311
# violation: 0.0065835847017966164
# violation: 0.006474664183039061
# violation: 0.006326262123582301
# violation: 0.006125210426861397
# violation: 0.005877366552423136
# violation: 0.005610667593110724
# violation: 0.005318922372096078
# violation: 0.0050118812133542225
# violation: 0.004702023955871363
# violation: 0.004412533515856144
# violation: 0.004124607899753155
# violation: 0.0038502700786859985
# violation: 0.0035872211445771105
# violation: 0.0033332848982407792
# violation: 0.0030955501271695894
# violation: 0.002868209507025879
# violation: 0.0026562599623375896
# violation: 0.0024605901206589103
# violation: 0.0022784526379222175
# violation: 0.002113055583355039
# violation: 0.001966087763409083
# violation: 0.0018355925109121575
# violation: 0.00171974031057095
# violation: 0.0016162149923102083
# violation: 0.001525413106232265
# violation: 0.0014468944889752782
# violation: 0.0013794820624257885
# violation: 0.0013220358221820037
# violation: 0.0012732207198356417
# violation: 0.001231435091801551
# violation: 0.0011963003514040653
# violation: 0.0011682876996092486
# violation: 0.0011456917989933566
# violation: 0.0011272680224368044
# violation: 0.0011127783373933292
# violation: 0.001101609976942609
# violation: 0.0010931269248653478
# violation: 0.0010839942702638309
# violation: 0.0010787414920855442
# violation: 0.0010749727975531238
# violation: 0.001072741491633285
# violation: 0.0010684872521998863
# violation: 0.0010648939099885332
# violation: 0.0010629255582593321
# violation: 0.0010619275984908578
# violation: 0.0010612879526979355
# violation: 0.0010611531870154888
# violation: 0.001061245011981779
# violation: 0.00106157518844752
# violation: 0.0010617167680136634
# violation: 0.0010618412367029287
# violation: 0.0010620653876373047
# violation: 0.0010614642705894977
# violation: 0.0010623663830250933
# violation: 0.0010631179367808826
# violation: 0.0010631531098702627
# violation: 0.0010630600151222056
# violation: 0.001062968903788537
# violation: 0.0010631644153465572
# violation: 0.0010635968289621073
# violation: 0.001063913551351105
# violation: 0.0010637920834306244
# violation: 0.0010636042086846517
# violation: 0.0010634943401538323
# violation: 0.0010624705907152031
# violation: 0.001061765176563018
# violation: 0.0010612850766535133
# violation: 0.0010611602197548539
# violation: 0.0010611014195890498
# violation: 0.0010615933886271524
# violation: 0.0010630087613877396
# violation: 0.0010654330753210417
# violation: 0.0010685822576893273
# violation: 0.0010722954608324371
# violation: 0.0010766052365865913
# violation: 0.001081524847019617
# violation: 0.0010873069705193516
# violation: 0.0010939250197169335
# violation: 0.001102412820074734
# violation: 0.0011113417601788316
# violation: 0.0011213508969131673
# violation: 0.0011328089303925496
# violation: 0.0011453862170835514
# violation: 0.0011589017060770481
# violation: 0.0011734637113655236
# violation: 0.0011892434426354153
# violation: 0.0012059384903331564
# violation: 0.001223061431107662
# violation: 0.0012399154122498023
# violation: 0.0012558180946329574
# violation: 0.001271776418704143
# violation: 0.0012879065897436854
# violation: 0.0013034934811836725
# violation: 0.0013168482966968327
# violation: 0.0013292250566244957
# violation: 0.0013374900097764628
# violation: 0.0013409922014059456
# violation: 0.0013409333968878766
# violation: 0.001339002476345074
# violation: 0.0013345610016303555
# violation: 0.0013274327271119146
# violation: 0.0013167061714912675
# violation: 0.0013032052794410677
# violation: 0.0012874834747616127
# violation: 0.0012685404022003987
# violation: 0.0012473346255010077
# violation: 0.001225490713366627
# violation: 0.0012040885418861508
# violation: 0.0011883667196907436
# violation: 0.0011729704069214056
# violation: 0.0011559655790060943
# violation: 0.0010969830034903664
# violation: 0.0010742570695616244
# violation: 0.00103725310628489
# violation: 0.0009992422615614977
# violation: 0.0009604836535762756
# violation: 0.000922112473359137
# violation: 0.0008838162977807433
# violation: 0.0008469988122511199
# violation: 0.0008119503368683663
# violation: 0.0007782678310282021
# violation: 0.0007460455463104736
# violation: 0.0007152770521631356
# violation: 0.0006855074422510147
# violation: 0.000656917614856338
# violation: 0.0006293539317318971
# violation: 0.0006030087137159207
# violation: 0.0005777645908872442
# violation: 0.0005531069454077348
# violation: 0.000529673112392422
# violation: 0.0005072339236440122
# violation: 0.00048592333490384123
# violation: 0.0004653821160411122
# violation: 0.0004457450616509211
# violation: 0.00042679218026672836
# violation: 0.00040824652488481803
# violation: 0.0003905119752632928
# violation: 0.00037369565481861405
# violation: 0.0003577187761581111
# violation: 0.00034253662562016673
# violation: 0.0003279934429997516
# violation: 0.0003139026522799198
# violation: 0.0003004155299125668
# violation: 0.00028772781148919777
# violation: 0.00027559582049404505
# violation: 0.000263994547571924
# violation: 0.0002529372444976128
# violation: 0.00024238357616507977
# violation: 0.00023234611751495515
# violation: 0.00022267830708038607
# violation: 0.0002134409439993589
# violation: 0.0002046227638504836
# violation: 0.00019620896894875767
# violation: 0.00018818765285145793
# violation: 0.00018052041340146103
# violation: 0.00017313773027505738
# violation: 0.00016611870582079535
# violation: 0.00015945756568359922
# violation: 0.0001530654889221154
# violation: 0.00014686863207399848
# violation: 0.00014084178571340726
# violation: 0.00013510340106095877
# violation: 0.00012963699017852812
# violation: 0.00012438001977948735
# violation: 0.00011933402683156545
# violation: 0.00011450220525666637
# violation: 0.000109511449931548
# violation: 0.00010447830670120133
# violation: 9.990097038772577e-05
# Converged at iteration 196

# %%
from pprint import pprint
def print_topics(model, vectorizer, top_n=15):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        pprint([(vectorizer.get_feature_names()[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])

# %%
# Keywords for topics clustered by Latent Dirichlet Allocation
print("LDA Model:")
print_topics(lda, vectorizer)
# Out:
# LDA Model:
# Topic 0:
# ['pitää',
#  'suomessa',
#  'saa',
#  'rouva',
#  'pitäisi',
#  'saada',
#  'huomiota',
#  'ihmisten',
#  'osa',
#  'ihmiset',
#  'ongelma',
#  'käytännössä',
#  'tilanteen',
#  'määrä',
#  'maksaa']
# Topic 1:
# ['työtä',
#  'työn',
#  'työ',
#  'töitä',
#  'työpaikkoja',
#  'työllisyyttä',
#  'puhumme',
#  'naisten',
#  'töihin',
#  'ihmisiä',
#  'osa',
#  'työntekijöiden',
#  'toimia',
#  'työllisyyden',
#  'yritysten']
# Topic 2:
# ['ongelmaa',
#  'suinkaan',
#  'alkoholin',
#  'helsinki',
#  'veteraanien',
#  'osoitus',
#  'velan',
#  'minkään',
#  'stä',
#  'alkoholilain',
#  'taustalla',
#  'alkon',
#  'sotiemme',
#  'kulttuuriin',
#  'höpö']
# Topic 3:
# ['perustuslain',
#  'laki',
#  'lain',
#  'lainsäädännön',
#  'oikeus',
#  'perustuslakivaliokunta',
#  'perustuslakivaliokunnan',
#  'viranomaisten',
#  'hallinto',
#  'lainsäädäntöä',
#  'kansalaisten',
#  'lainsäädäntö',
#  'lakia',
#  'henkilö',
#  'lailla']
# Topic 4:
# ['edustaja',
#  'esille',
#  'pitää',
#  'mielestäni',
#  'nimenomaan',
#  'kysymys',
#  'rouva',
#  'asiassa',
#  'sanoa',
#  'pitäisi',
#  'toivon',
#  'eteenpäin',
#  'keskustelua',
#  'mieltä',
#  'todellakin']
# Topic 5:
# ['ministeri',
#  'osalta',
#  'saadaan',
#  'ministeriltä',
#  'tulevaisuudessa',
#  'liikkeelle',
#  'pystytään',
#  'rouva',
#  'valtion',
#  'jatkossa',
#  'alueella',
#  'tullaan',
#  'tehdään',
#  'suurta',
#  'kysyisin']
# Topic 6:
# ['hallitus',
#  'hallituksen',
#  'euroa',
#  'liittyvät',
#  'kaikkein',
#  'verotuksen',
#  'verotusta',
#  'eläkeläisten',
#  'prosenttia',
#  'verotus',
#  'leikkaukset',
#  'pienituloisten',
#  'euron',
#  'kuukaudessa',
#  'asumistuen']
# Topic 7:
# ['luonnon',
#  'metsähallituksen',
#  'auton',
#  'metsähallitus',
#  'saamelaisten',
#  'monimuotoisuuden',
#  'norjan',
#  'olisinkin',
#  'lohi',
#  'kilometrin',
#  'kesänä',
#  'luonnonvarojen',
#  'pakolaisten',
#  'luontoa',
#  'liito']
# Topic 8:
# ['tiedän',
#  'päivänä',
#  'suomen',
#  'kunnossa',
#  'eduskuntaryhmä',
#  'ala',
#  'tällaiset',
#  'saa',
#  'luvulla',
#  'tietävät',
#  'nissilä',
#  'pientä',
#  'maailman',
#  'varrella',
#  'elää']
# Topic 9:
# ['eduskunnan',
#  'heinonen',
#  'paikalla',
#  'puheenvuoron',
#  'timo',
#  'ajattelen',
#  'puolueet',
#  'puheenjohtaja',
#  'sosiaali',
#  'perussuomalaisten',
#  'eduskunta',
#  'edustajat',
#  'totean',
#  'hallituspuolueiden',
#  'juttu']
# Topic 10:
# ['euroopan',
#  'suomen',
#  'maiden',
#  'suomi',
#  'euroopassa',
#  'turvallisuus',
#  'pohjoismaiden',
#  'turvapaikanhakijoiden',
#  'turvallisuutta',
#  'selonteossa',
#  'vuonna',
#  'ulkoministeri',
#  'laittomasti',
#  'maassa',
#  'ennalta']
# Topic 11:
# ['miljoonaa',
#  'euroa',
#  'vuonna',
#  'talouden',
#  'suomen',
#  'euron',
#  'hallitus',
#  'miljoonan',
#  'valtion',
#  'miljardia',
#  'hallituksen',
#  'julkisen',
#  'talous',
#  'rahaa',
#  'kasvu']
# Topic 12:
# ['ministeri',
#  'pääministeri',
#  'zyskowicz',
#  'sdp',
#  'perussuomalaiset',
#  'perussuomalaisten',
#  'hallitus',
#  'ben',
#  'orpo',
#  'kokoomuksen',
#  'hallituksen',
#  'heinäluoma',
#  'sipilä',
#  'eero',
#  'valtiovarainministeri']
# Topic 13:
# ['maa',
#  'maatalouden',
#  'venäjän',
#  'ruotsi',
#  'kaupan',
#  'suomella',
#  'venäjä',
#  'itämeren',
#  'nato',
#  'alueella',
#  'maatalous',
#  'maan',
#  'metsätalouden',
#  'usa',
#  'isis']
# Topic 14:
# ['prosenttia',
#  'suomessa',
#  'metsien',
#  'edistää',
#  'suomalaisen',
#  'yhtiön',
#  'raaka',
#  'suomalainen',
#  'osuus',
#  'tukea',
#  'kotimaista',
#  'investointeja',
#  'teollisuuden',
#  'merkittävä',
#  'päästöjä']
# Topic 15:
# ['varapuhemies',
#  'pekkarinen',
#  'mauri',
#  'ministeri',
#  'koputtaa',
#  'puheenvuoron',
#  'satonen',
#  'herra',
#  'arto',
#  'puhujalistaan',
#  'myönnän',
#  'haatainen',
#  'tuula',
#  'lailla',
#  'ministerille']
# Topic 16:
# ['sote',
#  'sosiaali',
#  'kuntien',
#  'palvelut',
#  'uudistuksen',
#  'uudistus',
#  'terveydenhuollon',
#  'kunnat',
#  'palveluiden',
#  'palveluita',
#  'kunnissa',
#  'palvelujen',
#  'kunnan',
#  'maakuntien',
#  'palveluja']
# Topic 17:
# ['kysyn',
#  'kysymyksiä',
#  'sopimuksen',
#  'kansanedustajat',
#  'taloudellista',
#  'oikealta',
#  'arhinmäki',
#  'loppuu',
#  'vievät',
#  'vastuun',
#  'keskusteltu',
#  'voisitteko',
#  'kertoa',
#  'naisiin',
#  'erään']
# Topic 18:
# ['kustannuksia',
#  'helsingin',
#  'lähtökohtaisesti',
#  'alalla',
#  'ely',
#  'kuultu',
#  'oltaisiin',
#  'tosiaankin',
#  'pystytä',
#  'kaupungin',
#  'kunnille',
#  'vapaan',
#  'potilaan',
#  'ilolla',
#  'lääkkeitä']
# Topic 19:
# ['liikenteen',
#  'kelan',
#  'riski',
#  'vr',
#  'oikeusasiamiehen',
#  'kela',
#  'saatavuus',
#  'auto',
#  'malmin',
#  'oikeuskanslerin',
#  'autojen',
#  'ripeästi',
#  'kertomuksessa',
#  'näe',
#  'kertomuksen']
# Topic 20:
# ['maria',
#  'lohela',
#  'pyydän',
#  'edustajia',
#  'esittää',
#  'harmaan',
#  'eläkkeensaajien',
#  'painiketta',
#  'työtön',
#  'malli',
#  'ilmoittautumaan',
#  'lisäkysymyksiä',
#  'aikaisemminkin',
#  'seisomaan',
#  'nousemaan']
# Topic 21:
# ['lasten',
#  'lapsen',
#  'tasa',
#  'lapset',
#  'varhaiskasvatuksen',
#  'lapsi',
#  'oikeus',
#  'perheiden',
#  'oikeuksien',
#  'perheen',
#  'varhaiskasvatukseen',
#  'vanhempien',
#  'arvoa',
#  'päivähoito',
#  'oikeuden']
# Topic 22:
# ['hallitus',
#  'hallituksen',
#  'koputtaa',
#  'tehdä',
#  'pitää',
#  'rouva',
#  'suomen',
#  'päätöksiä',
#  'tilanteessa',
#  'suomessa',
#  'edustaja',
#  'tehty',
#  'tekemään',
#  'suomi',
#  'tekee']
# Topic 23:
# ['henkilön',
#  'nuoren',
#  'henkilö',
#  'biaudet',
#  'henkilöä',
#  'omaishoitajien',
#  'eva',
#  'hankkia',
#  'mahdotonta',
#  'henkilöt',
#  'yt',
#  'opettajia',
#  'turun',
#  'kansalaisjärjestöjen',
#  'tulevasta']
# Topic 24:
# ['tärkeää',
#  'yhteistyötä',
#  'turvallisuuden',
#  'toiminnan',
#  'ylen',
#  'eduskunnan',
#  'yle',
#  'yhteistyö',
#  'toimintaa',
#  'pidän',
#  'sisäisen',
#  'yhteistyön',
#  'tärkeänä',
#  'kehityksen',
#  'puolustusvoimien']
# Topic 25:
# ['eu',
#  'suomen',
#  'suomi',
#  'euroopan',
#  'unionin',
#  'suomessa',
#  'maailman',
#  'liikenne',
#  'yk',
#  'ilmastonmuutoksen',
#  'kestävän',
#  'neuvoston',
#  'maissa',
#  'kansainvälistä',
#  'energian']
# Topic 26:
# ['hallituksen',
#  'esitys',
#  'valiokunta',
#  'esityksen',
#  'esityksessä',
#  'lain',
#  'valiokunnan',
#  'ehdotetaan',
#  'eduskunta',
#  'jatkossa',
#  'käsittelyssä',
#  'muutos',
#  'laki',
#  'esitystä',
#  'osalta']
# Topic 27:
# ['att',
#  'och',
#  'det',
#  'är',
#  'som',
#  'för',
#  'på',
#  'vi',
#  'har',
#  'den',
#  'talman',
#  'av',
#  'här',
#  'till',
#  'inte']
# Topic 28:
# ['aloitteen',
#  'kansalaisaloitteen',
#  'kansalaisaloite',
#  'lapsia',
#  'aloite',
#  'ihmisen',
#  'suomessa',
#  'lakialoite',
#  'lakialoitteen',
#  'oikeus',
#  'hoitoa',
#  'yhteiskunnan',
#  'säädetty',
#  'tilanteissa',
#  'ihmisten']
# Topic 29:
# ['koulutuksen',
#  'nuorten',
#  'tärkeää',
#  'koulutukseen',
#  'tukea',
#  'koulutus',
#  'nuoret',
#  'asteen',
#  'tarvitaan',
#  'ammatillisen',
#  'tärkeä',
#  'koulutusta',
#  'mahdollisuus',
#  'tulevaisuudessa',
#  'osa']

# %%
# Keywords for topics clustered by Non-Negative Matrix Factorization
print("NMF Model:")
print_topics(nmf, vectorizer)
# Out:
# NMF Model:
# Topic 0:
# ['hallitus',
#  'tekee',
#  'pääministeri',
#  'tehnyt',
#  'leikkaukset',
#  'sipilän',
#  'kaikkein',
#  'eduskunta',
#  'leikkaa',
#  'eduskunnan',
#  'edellinen',
#  'leikkauksia',
#  'leikata',
#  'koulutuksesta',
#  'esittää']
# Topic 1:
# ['att',
#  'och',
#  'det',
#  'är',
#  'som',
#  'för',
#  'på',
#  'vi',
#  'har',
#  'den',
#  'inte',
#  'av',
#  'här',
#  'till',
#  'med']
# Topic 2:
# ['edustaja',
#  'varapuhemies',
#  'mieltä',
#  'sanoi',
#  'totesi',
#  'kysyi',
#  'pekkarinen',
#  'mauri',
#  'heinonen',
#  'zyskowicz',
#  'totta',
#  'puheenvuoron',
#  'no',
#  'sanoa',
#  'edustajat']
# Topic 3:
# ['suomen',
#  'suomi',
#  'suomeen',
#  'maan',
#  'pankin',
#  'suomalaisten',
#  'maailman',
#  'ruotsin',
#  'irakin',
#  'yk',
#  'kansainvälisen',
#  'ulko',
#  'kehityksen',
#  'suomea',
#  'kestävän']
# Topic 4:
# ['euroa',
#  'miljoonaa',
#  'euron',
#  'miljoonan',
#  'miljardia',
#  'vuodelle',
#  'eurolla',
#  'vuonna',
#  'miljoonalla',
#  'rahaa',
#  'esitetään',
#  'vuodessa',
#  'kuukaudessa',
#  'osoitetaan',
#  'kehittämiseen']
# Topic 5:
# ['vuonna',
#  'prosenttia',
#  'määrä',
#  'prosentin',
#  'kelan',
#  'vuoteen',
#  'kuntien',
#  'miljardia',
#  'osuus',
#  'osa',
#  'prosenttiin',
#  'verrattuna',
#  'kasvu',
#  'kasvaa',
#  'vuodesta']
# Topic 6:
# ['hallituksen',
#  'esitys',
#  'esityksen',
#  'esityksessä',
#  'esitystä',
#  'sipilän',
#  'edellisen',
#  'leikkaukset',
#  'esitykseen',
#  'linja',
#  'pääministeri',
#  'työllisyyttä',
#  'sdp',
#  'kokoomuksen',
#  'opposition']
# Topic 7:
# ['pitää',
#  'saada',
#  'muistaa',
#  'pystyä',
#  'kiinni',
#  'huolta',
#  'ottaa',
#  'totta',
#  'tarvitaan',
#  'saadaan',
#  'tarvitsemme',
#  'mieltä',
#  'maassa',
#  'katsoa',
#  'pidä']
# Topic 8:
# ['eu',
#  'suomi',
#  'maiden',
#  'komission',
#  'maatalouden',
#  'britannian',
#  'unionin',
#  'suomelle',
#  'tasolla',
#  'komissio',
#  'pariisin',
#  'perussuomalaiset',
#  'sopimuksen',
#  'maat',
#  'ta']
# Topic 9:
# ['lapsen',
#  'lasten',
#  'lapsi',
#  'varhaiskasvatuksen',
#  'oikeus',
#  'lapset',
#  'lapsia',
#  'vanhempien',
#  'varhaiskasvatukseen',
#  'lapselle',
#  'perheen',
#  'perheiden',
#  'lasta',
#  'etu',
#  'edun']
# Topic 10:
# ['valiokunta',
#  'valiokunnan',
#  'huomiota',
#  'toteaa',
#  'tärkeänä',
#  'korostaa',
#  'kiinnittää',
#  'eduskunnan',
#  'mietinnössään',
#  'eduskunta',
#  'selvityksen',
#  'katsoo',
#  'edellyttää',
#  'pitää',
#  'perustuslakivaliokunta']
# Topic 11:
# ['koulutuksen',
#  'ammatillisen',
#  'nuorten',
#  'asteen',
#  'koulutukseen',
#  'koulutus',
#  'koulutusta',
#  'opiskelijoiden',
#  'koulutuksesta',
#  'leikkaukset',
#  'reformin',
#  'osaamisen',
#  'reformi',
#  'tulevaisuuden',
#  'nuoret']
# Topic 12:
# ['sote',
#  'sosiaali',
#  'uudistuksen',
#  'uudistus',
#  'terveydenhuollon',
#  'palvelut',
#  'palveluiden',
#  'kuntien',
#  'palveluita',
#  'palvelujen',
#  'maakunnan',
#  'uudistusta',
#  'maakuntien',
#  'ihmisten',
#  'maakunta']
# Topic 13:
# ['ministeri',
#  'orpo',
#  'minuuttia',
#  'varapuhemies',
#  'lindström',
#  'risikko',
#  'kysymys',
#  'ministerin',
#  'kysyn',
#  'sanoi',
#  'paula',
#  'totesi',
#  'kysyisin',
#  'paikalla',
#  'soini']
# Topic 14:
# ['suomessa',
#  'suomeen',
#  'maassa',
#  'ruotsissa',
#  'suomesta',
#  'suomalainen',
#  'suomalaisen',
#  'maissa',
#  'määrä',
#  'suomalaiset',
#  'laittomasti',
#  'saa',
#  'suomalaisten',
#  'maailman',
#  'tarvitaan']
# Topic 15:
# ['talouden',
#  'julkisen',
#  'työn',
#  'talous',
#  'työllisyyden',
#  'euron',
#  'kasvu',
#  'kasvun',
#  'harmaan',
#  'työllisyyttä',
#  'kasvua',
#  'työtä',
#  'miljardin',
#  'yritysten',
#  'miljoonan']
# Topic 16:
# ['tehdä',
#  'tehdään',
#  'työtä',
#  'päätöksiä',
#  'tekemään',
#  'tehty',
#  'toimia',
#  'työn',
#  'voitaisiin',
#  'töitä',
#  'mahdollisuus',
#  'teemme',
#  'tarvitsemme',
#  'ratkaisuja',
#  'muutoksia']
# Topic 17:
# ['lain',
#  'esitys',
#  'esityksen',
#  'esityksessä',
#  'laki',
#  'ehdotetaan',
#  'jatkossa',
#  'eduskunnan',
#  'perustuslain',
#  'voimaan',
#  'oikeus',
#  'muutos',
#  'perustuslakivaliokunnan',
#  'voimassa',
#  'laissa']
# Topic 18:
# ['osalta',
#  'osin',
#  'eteenpäin',
#  'tehty',
#  'kuntien',
#  'ollaan',
#  'tehdään',
#  'liikenteen',
#  'tietenkin',
#  'tullaan',
#  'liittyy',
#  'näitten',
#  'liittyen',
#  'osa',
#  'keskustelua']
# Topic 19:
# ['esille',
#  'nostaa',
#  'tuli',
#  'kelan',
#  'toi',
#  'nosti',
#  'oikeusasiamiehen',
#  'keskustelussa',
#  'otti',
#  'ottaa',
#  'elikkä',
#  'eduskunnan',
#  'todellakin',
#  'tuoda',
#  'huomiota']
# Topic 20:
# ['euroopan',
#  'unionin',
#  'suomi',
#  'neuvoston',
#  'venäjän',
#  'pohjoismaiden',
#  'venäjä',
#  'unioni',
#  'yhteistyötä',
#  'tilanne',
#  'euroopassa',
#  'turvallisuuden',
#  'yleiskokouksen',
#  'unionissa',
#  'ulko']
# Topic 21:
# ['tärkeää',
#  'tärkeä',
#  'tarvitaan',
#  'äärimmäisen',
#  'työtä',
#  'saadaan',
#  'todellakin',
#  'tukea',
#  'eteenpäin',
#  'jatkossa',
#  'erityisen',
#  'nuorten',
#  'tietenkin',
#  'tärkeitä',
#  'saada']
# Topic 22:
# ['koputtaa',
#  'varapuhemies',
#  'herra',
#  'pekkarinen',
#  'mauri',
#  'välihuutoja',
#  'pääministeri',
#  'hälinää',
#  'puheenvuoron',
#  'kysymys',
#  'sdp',
#  'välihuuto',
#  'kaudella',
#  'minuuttia',
#  'edustajat']
# Topic 23:
# ['valtion',
#  'kuntien',
#  'valtio',
#  'metsähallituksen',
#  'metsähallitus',
#  'yhtiön',
#  'miljardia',
#  'yhtiöiden',
#  'maa',
#  'oy',
#  'kehitysyhtiön',
#  'eduskunnan',
#  'maakuntien',
#  'kunnat',
#  'valtioneuvoston']
# Topic 24:
# ['rouva',
#  'maria',
#  'lohela',
#  'risikko',
#  'paula',
#  'toivon',
#  'saadaan',
#  'ministeriltä',
#  'pidän',
#  'tulevaisuudessa',
#  'maassa',
#  'kaudella',
#  'pääministeri',
#  'kysyn',
#  'tilanne']
# Topic 25:
# ['pitäisi',
#  'saada',
#  'mieltä',
#  'ongelma',
#  'ottaa',
#  'pystyä',
#  'prosenttia',
#  'rahaa',
#  'puhutaan',
#  'voitaisiin',
#  'miettiä',
#  'pois',
#  'käyttää',
#  'ihmisiä',
#  'päästä']
# Topic 26:
# ['tasa',
#  'suomi',
#  'naisten',
#  'arvon',
#  'arvoa',
#  'työn',
#  'arvo',
#  'kehityksen',
#  'kestävän',
#  'ihmisten',
#  'maailman',
#  'työtä',
#  'yhteiskunnan',
#  'lasten',
#  'osa']
# Topic 27:
# ['kysymys',
#  'saa',
#  'asiassa',
#  'sanoa',
#  'ihmiset',
#  'elikkä',
#  'toivon',
#  'eteenpäin',
#  'tilanne',
#  'ihmisiä',
#  'tehdään',
#  'ihmisten',
#  'työtä',
#  'ollaan',
#  'no']
# Topic 28:
# ['nimenomaan',
#  'jatkossa',
#  'mielessä',
#  'asiassa',
#  'huomiota',
#  'kaikkein',
#  'tosiaan',
#  'näkökulmasta',
#  'ikään',
#  'liittyy',
#  'ollaan',
#  'totta',
#  'saadaan',
#  'puhutaan',
#  'oikeastaan']
# Topic 29:
# ['mielestäni',
#  'tietenkin',
#  'pidän',
#  'asiassa',
#  'ylen',
#  'yle',
#  'toivon',
#  'keskustelua',
#  'mielessä',
#  'mieltä',
#  'herra',
#  'ikään',
#  'keskustelussa',
#  'sanoa',
#  'keskustelu']

# %%
#pyLDAvis.enable_notebook()
#eduskunta_vis_data = pyLDAvis.sklearn.prepare(lda, data_vectorized, vectorizer, mds='tsne')

# %% [markdown]
# ## Topic modelling with Gensim

# %%
print('test')
