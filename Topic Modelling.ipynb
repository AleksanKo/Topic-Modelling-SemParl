# %% [markdown]
# ## Topic modelling with Scikit-learn

# %%
import re
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %%
data = pd.read_csv('final.csv', sep='\t',header = None,names = ['ID','Date','Time','Speaker','Party','Text'])
display(data[0:5])
# Out:
#    ID        Date      Time          Speaker Party  \
# 3   3  2018-05-16  14:20:32  Maria Tolppanen    sd
# 4   4  2018-05-16  14:21:37  Jari Myllykoski   vas
#
#                                                 Text
# 3   Arvoisa puhemies! Tässä nyt täytyy ensin tode...
# 4   Arvoisa herra puhemies! Kaksi tässä edellä kä...

# %%
stopwords = ["aiemmin","aika","aikaa","aikaan","aikaisemmin","aikaisin","aikajen","aikana","aikoina","aikoo","aikovat","aina","ainakaan","ainakin","ainoa","ainoat","aiomme","aion","aiotte","aist","aivan","ajan","alas","alemmas","alkuisin","alkuun","alla","alle","aloitamme","aloitan","aloitat","aloitatte","aloitattivat","aloitettava","aloitettevaksi","aloitettu","aloitimme","aloitin","aloitit","aloititte","aloittaa","aloittamatta","aloitti","aloittivat","alta","aluksi","alussa","alusta","annettavaksi","annetteva","annettu","ansiosta","antaa","antamatta","antoi","aoua","apu","asia","asiaa","asian","asiasta","asiat","asioiden","asioihin","asioita","asti","avuksi","avulla","avun","avutta","edelle","edelleen","edellä","edeltä","edemmäs","edes","edessä","edestä","ehkä","ei","eikä","eilen","eivät","eli","ellei","elleivät","ellemme","ellen","ellet","ellette","emme","en","enemmän","eniten","ennen","ensi","ensimmäinen","ensimmäiseksi","ensimmäisen","ensimmäisenä","ensimmäiset","ensimmäisiksi","ensimmäisinä","ensimmäisiä","ensimmäistä","ensin","entinen","entisen","entisiä","entisten","entistä","enää","eri","erittäin","erityisesti","eräiden","eräs","eräät","esi","esiin","esillä","esimerkiksi","et","eteen","etenkin","etessa","ette","ettei","että","haikki","halua","haluaa","haluamatta","haluamme","haluan","haluat","haluatte","haluavat","halunnut","halusi","halusimme","halusin","halusit","halusitte","halusivat","halutessa","haluton","he","hei","heidän","heidät","heihin","heille","heillä","heiltä","heissä","heistä","heitä","helposti","heti","hetkellä","hieman","hitaasti","hoikein","huolimatta","huomenna","hyvien","hyviin","hyviksi","hyville","hyviltä","hyvin","hyvinä","hyvissä","hyvistä","hyviä","hyvä","hyvät","hyvää","hän","häneen","hänelle","hänellä","häneltä","hänen","hänessä","hänestä","hänet","häntä","ihan","ilman","ilmeisesti","itse","itsensä","itseään","ja","jo","johon","joiden","joihin","joiksi","joilla","joille","joilta","joina","joissa","joista","joita","joka","jokainen","jokin","joko","joksi","joku","jolla","jolle","jolloin","jolta","jompikumpi","jona","jonka","jonkin","jonne","joo","jopa","jos","joskus","jossa","josta","jota","jotain","joten","jotenkin","jotenkuten","jotka","jotta","jouduimme","jouduin","jouduit","jouduitte","joudumme","joudun","joudut
haiten","perusteella","peräti","pian","pieneen","pieneksi","pienelle","pienellä","pieneltä","pienempi","pienestä","pieni","pienin","poikki","puolesta","puolestaan","päälle","runsaasti","saakka","sadam","sama","samaa","samaan","samalla","samallalta","samallassa","samallasta","saman","samat","samoin","sata","sataa","satojen","se","seitsemän","sekä","sen","seuraavat","siellä","sieltä","siihen","siinä","siis","siitä","sijaan","siksi","sille","silloin","sillä","silti","siltä","sinne","sinua","sinulla","sinulle","sinulta","sinun","sinussa","sinusta","sinut","sinuun","sinä","sisäkkäin","sisällä","siten","sitten","sitä","ssa","sta","suoraan","suuntaan","suuren","suuret","suuri","suuria","suurin","suurten","taa","taas","taemmas","tahansa","tai","takaa","takaisin","takana","takia","tallä","tapauksessa","tarpeeksi","tavalla","tavoitteena","te","teidän","teidät","teihin","teille","teillä","teiltä","teissä","teistä","teitä","tietysti","todella","toinen","toisaalla","toisaalle","toisaalta","toiseen","toiseksi","toisella","toiselle","toiselta","toisemme","toisen","toisensa","toisessa","toisesta","toista","toistaiseksi","toki","tosin","tuhannen","tuhat","tule","tulee","tulemme","tulen","tulet","tulette","tulevat","tulimme","tulin","tulisi","tulisimme","tulisin","tulisit","tulisitte","tulisivat","tulit","tulitte","tulivat","tulla","tulleet","tullut","tuntuu","tuo","tuohon","tuoksi","tuolla","tuolle","tuolloin","tuolta","tuon","tuona","tuonne","tuossa","tuosta","tuota","tuotä","tuskin","tykö","tähän","täksi","tälle","tällä","tällöin","tältä","tämä","tämän","tänne","tänä","tänään","tässä","tästä","täten","tätä","täysin","täytyvät","täytyy","täällä","täältä","ulkopuolella","usea","useasti","useimmiten","usein","useita","uudeksi","uudelleen","uuden","uudet","uusi","uusia","uusien","uusinta","uuteen","uutta","vaan","vahemmän","vai","vaiheessa","vaikea","vaikean","vaikeat","vaikeilla","vaikeille","vaikeilta","vaikeissa","vaikeista","vaikka","vain","varmasti","varsin","varsinkin","varten","vasen","vasenmalla","vasta","vastaan","vastakkain","vastan","verran","vielä","vierekkäin","vieressä","vieri","viiden","viime","viimeinen","viimeisen","viimeksi","viisi","voi","voidaan","voimme","voin","voisi","voit","voitte","voivat","vuoden","vuoksi","vuosi","vuosien","vuosina","vuotta","vähemmän","vähintään","vähiten","vähän","välillä","yhdeksän","yhden","yhdessä","yhteen","yhteensä","yhteydessä","yhteyteen","yhtä","yhtäälle","yhtäällä","yhtäältä","yhtään","yhä","yksi","yksin","yksittäin","yleensä","ylemmäs","yli","ylös","ympäri","älköön","älä"]

# %%
data['Text'] = [''.join([i for i in s if not i.isdigit()]) for s in data['Text']]
data['Text'] = [re.sub(r'[^\w]', ' ', i) for i in data['Text']]
data['Text'] = [re.sub(r' +', ' ', i) for i in data['Text']]

# %%
data['Text'][0:5]
# Out:
# 0     Arvoisa puhemies Lähetekeskusteluun olemme sa...
# 1     Arvoisa puhemies Käsillä on todella hallituks...
# 2    Arvoisa puhemies Ministeri maalasi kyllä aika ...
# 3     Arvoisa puhemies Tässä nyt täytyy ensin todet...
# 4     Arvoisa herra puhemies Kaksi tässä edellä käy...
# Name: Text, dtype: object

# %%
# Creating a vectorizer
vectorizer = CountVectorizer(min_df=5, max_df=0.9, lowercase=True, stop_words = stopwords,analyzer='word')
data_vectorized = vectorizer.fit_transform(data['Text'])
data_vectorized
# Out:
# <56659x90447 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5337279 stored elements in Compressed Sparse Row format>

# %%
NUM_TOPICS = 20

# %%
lda = LatentDirichletAllocation(n_components=NUM_TOPICS, max_iter=20, learning_method='online',verbose=True)
data_lda = lda.fit_transform(data_vectorized)
# Out:
# iteration: 1 of max_iter: 20
# iteration: 2 of max_iter: 20
# iteration: 3 of max_iter: 20
# iteration: 4 of max_iter: 20
# iteration: 5 of max_iter: 20
# iteration: 6 of max_iter: 20
# iteration: 7 of max_iter: 20
# iteration: 8 of max_iter: 20
# iteration: 9 of max_iter: 20
# iteration: 10 of max_iter: 20
# iteration: 11 of max_iter: 20
# iteration: 12 of max_iter: 20
# iteration: 13 of max_iter: 20
# iteration: 14 of max_iter: 20
# iteration: 15 of max_iter: 20
# iteration: 16 of max_iter: 20
# iteration: 17 of max_iter: 20
# iteration: 18 of max_iter: 20
# iteration: 19 of max_iter: 20
# iteration: 20 of max_iter: 20

# %%
nmf = NMF(n_components=NUM_TOPICS,verbose=True)
data_nmf = nmf.fit_transform(data_vectorized)
# Out:
# violation: 1.0
# violation: 0.42375565054607905
# violation: 0.29997033310738597
# violation: 0.20193504276542643
# violation: 0.1400352579460568
# violation: 0.09489773662351629
# violation: 0.07015940272830683
# violation: 0.06007910015844343
# violation: 0.05549469946967687
# violation: 0.048337408527562124
# violation: 0.039047546405194956
# violation: 0.03103498578612701
# violation: 0.024675647231405327
# violation: 0.019187697454691652
# violation: 0.01650960480781715
# violation: 0.014608251434116743
# violation: 0.013351113164975299
# violation: 0.012356466765034513
# violation: 0.011324482213861464
# violation: 0.010458160459341783
# violation: 0.00961116010945111
# violation: 0.008754588356523565
# violation: 0.007917063080745516
# violation: 0.007129466213079994
# violation: 0.006421872744438983
# violation: 0.005823849930228526
# violation: 0.005337128209242302
# violation: 0.0049488302269731985
# violation: 0.004588897912916102
# violation: 0.0042615255163001185
# violation: 0.004075638941295361
# violation: 0.003973006487117412
# violation: 0.003927901898715801
# violation: 0.0039182638318450425
# violation: 0.003937951871302586
# violation: 0.0039743397525682424
# violation: 0.00403038814216171
# violation: 0.00409366427272356
# violation: 0.004143686956381877
# violation: 0.004185857006192732
# violation: 0.004211288374801129
# violation: 0.004221728973691652
# violation: 0.004143837099050743
# violation: 0.004063130896427297
# violation: 0.0039826090563033914
# violation: 0.0038913480379810877
# violation: 0.0038075185342531367
# violation: 0.003715646171211909
# violation: 0.003634482854698202
        print(', '.join([vectorizer.get_feature_names()[i]
                        for i in topic.argsort()[:-top_n - 1:-1]]))

# %%
def print_topics_as_df(model, vectorizer, top_n=15):
    df1 = pd.DataFrame([None]*15,columns=['1'])

    for idx, topic in enumerate(model.components_):
        df2 = pd.DataFrame([vectorizer.get_feature_names()[i]
                        for i in topic.argsort()[:-top_n - 1:-1]],columns=["Topic %d" % (idx)])
        df1 = df1.join(df2)
    df1 = df1.drop('1',axis=1)
    return df1

# %%
# Keywords for topics clustered by Latent Dirichlet Allocation
print("LDA Model:")
print_topics_as_df(lda, vectorizer)
# Out:
# LDA Model:
#             Topic 0         Topic 1 Topic 2     Topic 3  \
# 0         eduskunta     koulutuksen     att     valtion
# 1        edellyttää         nuorten     och   miljoonaa
# 2   valtioneuvoston            tasa     det      vuonna
# 3           harmaan         naisten      är      suomen
# 4          suinkaan        koulutus     som       euroa
# 5        käsittelyn          asteen     för      osalta
# 6      vastalauseen    ammatillisen      på     tärkeää
# 7       selvityksen    koulutukseen      vi      tärkeä
# 8         mietinnön      koulutusta     har        ylen
# 9          mukainen  opiskelijoiden     den         yle
# 10       vammaisten           tukea  talman   arhinmäki
# 11         talouden          nuoria      av   miljoonan
# 12  oikeuskanslerin        nuorille     här  rahoitusta
# 13   valtioneuvosto      työelämään    till      valtio
# 14       eduskunnan            arvo    inte    rahoitus
#
#                     Topic 4           Topic 5      Topic 6       Topic 7  \
# 0                eduskunnan        prosenttia       esille        suomen
# 1                mielestäni        liikenteen      tärkeää      hallitus
# 2                 eduskunta          suomessa       tärkeä     yritysten
# 3                   kysymys             hinta        pitää          työn
# 4              eduskunnassa          asumisen   mielestäni   työpaikkoja
# 5                   asiassa             tukea       toivon         suomi
# 6              perustuslain          energian  keskustelua         työtä
# 7             lainsäädäntöä          maksavat    eteenpäin     yritykset
# 8                      laki          vuodessa        rouva    työttömyys
# 9                    oikeus           vuoteen        sanoa   hallituksen
# 10                      saa  lähtökohtaisesti    haluaisin     tarvitaan
# 11                tällainen             osuus     mielessä           työ
# 12                   toivon            vuokra    tietenkin    prosenttia
# 13  perustuslakivaliokunnan            maksaa     edustaja        kasvun
# 14            lainsäädännön   tulevaisuudesta   todellakin  työllisyyden
#
#          Topic 8     Topic 9        Topic 10           Topic 11  \
# 0       suomessa    edustaja          suomen              pitää
# 1        suomeen       pitää              eu             suomen
# 2         suomen       tehdä           suomi           suomessa
# 3         maassa     pitäisi        euroopan                maa
# 4          pitää      mieltä         unionin              suomi
# 5           maan     salissa          maiden                 eu
# 6          määrä  nimenomaan     yhteistyötä           maailman
# 7         maissa       sanoa  kansainvälisen        maatalouden
# 8   suomalaisten       rouva         venäjän  ilmastonmuutoksen
# 9            saa       totta       neuvoston         kehityksen
# 10      ihmisten    puhutaan   pohjoismaiden           kestävän
# 11       tilanne  mielestäni      euroopassa        suomalaisen
# 12   tilanteessa      esille        suomella        suomalainen
# 13   suomalaiset    koputtaa            ulko            metsien
# 14      suomesta     asiassa        hallitus             saamme
#
#               Topic 12     Topic 13          Topic 14      Topic 15  \
# 0               lasten     hallitus              sote      edustaja
# 1               lapsen  hallituksen          sosiaali     ministeri
# 2               oikeus        euroa          palvelut      koputtaa
# 3                 tasa    miljoonaa           kuntien      hallitus
# 4               lapset     talouden       uudistuksen  varapuhemies
# 5               lapsia       vuonna          uudistus   hallituksen
# 6                lapsi        euron       palveluiden       kysymys
# 7            perheiden    miljardia  terveydenhuollon    pekkarinen
# 8                   yk     kaikkein        palveluita         mauri
# 9   varhaiskasvatuksen    miljoonan        palvelujen         rouva
# 10             perheen  leikkaukset            kunnat  pääministeri
# 11            oikeutta   prosenttia         tarvitaan     edustajat
# 12          vanhempien     julkisen         palveluja     zyskowicz
# 13            lapsille       talous      kustannuksia        totesi
# 14            oikeuden        rahaa            hoidon  puheenvuoron
#
#           Topic 16    Topic 17      Topic 18     Topic 19
# 0         poliisin       pitää      liikenne  hallituksen
# 1   turvallisuuden     pitäisi  turvallisuus       esitys
# 2    viranomaisten  nimenomaan    liikenteen   valiokunta
# 3          poliisi      osalta        yhtiön  esityksessä
# 4     kansalaisten       tehdä        irakin    esityksen
# 5         huomiota       rouva     alkoholin         lain
# 6        poliisien         saa   yleisradion  valiokunnan
# 7   turvallisuutta       saada        vuonna       osalta
# 8         sisäisen      elikkä   selonteossa         laki
# 9            rouva     ihmiset            oy   ehdotetaan
# 10      toimintaan     tehdään  huolehditaan     jatkossa
# 11         ennalta     saadaan    merkittävä         osin
# 12       toimintaa         osa       pohjois     huomiota
# 13       tarvitaan     tilanne   rahoituksen     huomioon
# 14     henkilöstön     ongelma   terrorismin       muutos

# %% [markdown]
# In LDA model we can see such topics as:
#
# 1. **Topic 1**: education (related especially to youth and women)
# 2. **Topic 2**: stopwords from Swedish texts (some speeches are done partially or completely in Swedish)
# 3. **Topic 3**: funding
# 4. **Topic 4**: legislation
# 5. **Topic 7**: work and unemployment
# 6. **Topic 8**: Finland
# 7. **Topic 10**: external affairs
# 8. **Topic 12**: family and children
# 9. **Topic 13**: economics
# 10. **Topic 14**: social policy reforms
# 11. **Topic 16**: security

# %%
# Keywords for topics clustered by Non-Negative Matrix Factorization
print("NMF Model:")
print_topics_as_df(nmf, vectorizer)
# Out:
# NMF Model:
#           Topic 0 Topic 1       Topic 2         Topic 3        Topic 4  \
# 0        hallitus     att      edustaja          suomen          euroa
# 1           tekee     och  varapuhemies           suomi      miljoonaa
# 2    pääministeri     det        mieltä         suomeen          euron
# 3     leikkaukset      är         sanoi            maan      miljoonan
# 4          tehnyt     som        totesi          pankin      miljardia
# 5       eduskunta     för         kysyi        maailman       vuodelle
# 6         sipilän      på    pekkarinen    suomalaisten        eurolla
# 7        kaikkein      vi         totta         ruotsin    miljoonalla
# 8         leikkaa     har         mauri          irakin          rahaa
# 9      eduskunnan     den      heinonen              yk       vuodessa
# 10      edellinen    inte     zyskowicz  kansainvälisen      esitetään
# 11  koulutuksesta      av  puheenvuoron            ulko    kuukaudessa
# 12        leikata     här         sanoa          suomea     osoitetaan
# 13    leikkauksia    till            no             maa  kehittämiseen
# 14        esittää     med     edustajat   pohjoismaiden         euroon
#
#         Topic 5       Topic 6      Topic 7           Topic 8  \
# 0        vuonna   hallituksen        pitää                eu
# 1       kuntien        esitys        saada             suomi
# 2         määrä     esityksen      muistaa            maiden
# 3       vuoteen   esityksessä       kiinni         komission
# 4    eduskunnan      esitystä       pystyä       maatalouden
# 5     miljardia       sipilän       huolta        britannian
# 6       eurolla     edellisen        totta           unionin
# 7       tilanne   leikkaukset        ottaa          suomelle
# 8       asiassa    esitykseen      saadaan           tasolla
# 9     prosentin         linja    tarvitaan          komissio
# 10        euron  pääministeri          saa          pariisin
# 11     vuodelle           sdp       maassa  perussuomalaiset
# 12  miljoonalla   kokoomuksen  tarvitsemme        sopimuksen
# 13     vuodesta  työllisyyttä       mieltä              maat
# 14      voimaan    opposition     pystymme                ta
#
#                 Topic 9       Topic 10        Topic 11          Topic 12  \
# 0                lapsen     valiokunta     koulutuksen              sote
# 1                lasten    valiokunnan    ammatillisen          sosiaali
# 2                 lapsi       huomiota         nuorten       uudistuksen
# 3    varhaiskasvatuksen         toteaa          asteen          uudistus
# 4                oikeus       tärkeänä    koulutukseen  terveydenhuollon
# 5                lapset       korostaa        koulutus          palvelut
# 6                lapsia     kiinnittää            tasa       palveluiden
# 7            vanhempien     eduskunnan      koulutusta           kuntien
# 8   varhaiskasvatukseen          pitää  opiskelijoiden        palveluita
# 9                  tasa  mietinnössään   koulutuksesta        palvelujen
# 10             lapselle    selvityksen     leikkaukset         maakunnan
# 11            perheiden      eduskunta        reformin        uudistusta
# 12              perheen         katsoo       osaamisen        maakuntien
# 13                lasta     edellyttää         reformi          ihmisten
# 14                  etu       huomioon   tulevaisuuden          maakunta
#
#         Topic 13      Topic 14      Topic 15   Topic 16  \
# 0      ministeri      suomessa      talouden    pitäisi
# 1           orpo       suomeen      julkisen    kysymys
# 2      minuuttia        maassa        talous        saa
# 3   varapuhemies           saa       harmaan    asiassa
# 4        kysymys     ruotsissa         euron      sanoa
# 5      lindström      suomesta  työllisyyden     elikkä
# 6        risikko   suomalainen         kasvu      saada
# 7     ministerin         määrä        kasvun    ihmiset
# 8          sanoi        maissa        kasvua    tilanne
# 9          kysyn   suomalaisen     miljardin    ihmisiä
# 10         paula   laittomasti  työllisyyttä     ollaan
# 11        totesi   suomalaiset     miljardia         no
# 12      kysyisin  suomalaisten     miljoonan     toivon
# 13      paikalla        oikeus      taloutta  eteenpäin
# 14         soini      maailman     prosentin      rahaa
#
#                    Topic 17     Topic 18          Topic 19        Topic 20  \
# 0                      lain       osalta            esille        euroopan
# 1                    esitys         osin            nostaa         unionin
# 2                 esityksen    eteenpäin              tuli           suomi
# 3               esityksessä        tehty               toi       neuvoston
# 4                      laki      tehdään             nosti         venäjän
# 5                ehdotetaan       ollaan  oikeusasiamiehen   pohjoismaiden
# 6                eduskunnan      kuntien     keskustelussa          venäjä
# 7                  jatkossa   liikenteen              otti          unioni
# 8              perustuslain          osa             ottaa     yhteistyötä
# 9                   voimaan    tietenkin            elikkä         tilanne
# 10                   oikeus      tullaan             tuoda      euroopassa
# 11  perustuslakivaliokunnan      liittyy             kelan  turvallisuuden
# 12                   muutos      näitten        eduskunnan  yleiskokouksen
# 13                 voimassa     liittyen         eteenpäin       unionissa
# 14                   laissa  keskustelua        todellakin            ulko
#
#        Topic 21      Topic 22          Topic 23      Topic 24      Topic 25  \
# 0       tärkeää      koputtaa           valtion         tehdä    prosenttia
# 1        tärkeä  varapuhemies           kuntien       tehdään         kelan
# 2    todellakin         herra            valtio         työtä     prosentin
# 3   äärimmäisen    pekkarinen  metsähallituksen     päätöksiä           osa
# 4     tarvitaan         mauri     metsähallitus         tehty         osuus
# 5       saadaan  pääministeri            yhtiön      tekemään          kela
# 6     eteenpäin   välihuutoja         miljardia        toimia         määrä
# 7     tietenkin       kysymys         yhtiöiden    voitaisiin  eläkeläisten
# 8        toivon       hälinää               maa         töitä    tarkoittaa
# 9     erityisen  puheenvuoron                oy    eduskunnan      vuodessa
# 10        tukea     välihuuto     kehitysyhtiön        teemme   käytännössä
# 11     jatkossa           sdp        maakuntien  mahdollisuus       nuorten
# 12     tärkeitä      kaudella            kunnat         pakko   valtuutetut
# 13        saada     edustajat   valtioneuvoston     muutoksia     miljardia
# 14        pidän     minuuttia        eduskunnan    ratkaisuja        puolet
#
#            Topic 26      Topic 27      Topic 28       Topic 29
# 0             rouva          työn    nimenomaan     mielestäni
# 1            toivon         työtä       asiassa      tietenkin
# 2           saadaan          tasa      jatkossa          pidän
# 3             maria         suomi      mielessä        asiassa
# 4           risikko           osa        ollaan         toivon
# 5            lohela      ihmisten       saadaan           ylen
# 6             paula           työ      kaikkein            yle
# 7            maassa     tarvitaan         totta          herra
# 8           tilanne    kehityksen       tehdään    keskustelua
# 9   tulevaisuudessa  yhteiskunnan      huomiota       mielessä
# 10     ministeriltä      kestävän         tehty         mieltä
# 11            pidän       naisten         ikään          ikään
# 12       todellakin   tarvitsemme       tosiaan  keskustelussa
# 13         kaudella      maailman       liittyy        salissa
# 14           ollaan       ihmisiä  näkökulmasta     keskustelu

# %% [markdown]
# In NMF model we can see such topics as:
#
# 1. **Topic 0**: cuts
# 2. **Topic 1**: stopwords from Swedish texts (some speeches are done partially or completely in Swedish)
# 3. **Topic 9**: family and children
# 4. **Topic 11**: education and reforms
# 5. **Topic 12**: social policy reforms
# 6. **Topic 15**: economics and employment
# 7. **Topic 17**: law
# 8. **Topic 20**: foreign affairs
